# %%
# !rm -rf ./lightning-hydra-template

# %%
# !git clone https://github.com/atulgupta01/EMLO
# !mv ./EMLO/Assignment04/lightning-hydra-template .
# !rm -rf ./EMLO
# Out:
# Cloning into 'EMLO'...
# remote: Enumerating objects: 430, done.
# remote: Counting objects: 100% (138/138), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 430 (delta 87), reused 84 (delta 54), pack-reused 292
# Receiving objects: 100% (430/430), 155.96 KiB | 8.21 MiB/s, done.
# Resolving deltas: 100% (164/164), done.

# %%
# !pip install -r ./lightning-hydra-template/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python ./lightning-hydra-template/src/train.py experiment=cifar_example
# Out:
# Streaming output truncated to the last 5000 lines.
#                                     0:00:17                    v_num: 0
#                                                                val/loss: 0.818
#                                                                val/acc: 0.796
#                                                                hp_metric: 0.818
#                                                                val/acc_best:
#                                                                0.802 train/loss:
#                                                                0.121 train/acc:
# Epoch 9    ━━━━╸━━━━━━━━━━━ 117/392 0:00:06 •        16.87it/s loss: 0.0918
#                                     0:00:17                    v_num: 0
#                                                                val/loss: 0.818
#                                                                val/acc: 0.796
# ...

# %%
# !python ./lightning-hydra-template/src/demo_scripted.py ckpt_path=/content/lightning-hydra-template/logs/train/runs/2022-10-04_02-21-29/model.script.pt
# Out:
# [2022-10-04 02:30:28,412][__main__][INFO] - Running Demo
# [2022-10-04 02:30:28,412][__main__][INFO] - Instantiating scripted model </content/lightning-hydra-template/logs/train/runs/2022-10-04_02-21-29/model.script.pt>
# [2022-10-04 02:30:28,537][__main__][INFO] - Loaded Model: RecursiveScriptModule(
#   original_name=CIFARLitModule
#   (net): RecursiveScriptModule(
#     original_name=ResNet
#     (conv1): RecursiveScriptModule(original_name=Conv2d)
#     (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#     (act1): RecursiveScriptModule(original_name=ReLU)
#     (maxpool): RecursiveScriptModule(original_name=MaxPool2d)
#     (layer1): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(
#         original_name=BasicBlock
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (drop_block): RecursiveScriptModule(original_name=Identity)
# ...
