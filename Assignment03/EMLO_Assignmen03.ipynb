# %%
# !git clone https://github.com/atulgupta01/EMLO
# !mv ./EMLO/Assignment03/lightning-hydra-template .
# !rm -rf ./EMLO
# Out:
# Cloning into 'EMLO'...
# remote: Enumerating objects: 366, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 366 (delta 56), reused 36 (delta 33), pack-reused 292
# Receiving objects: 100% (366/366), 103.92 KiB | 10.39 MiB/s, done.
# Resolving deltas: 100% (133/133), done.
# rm: cannot remove './EMLO': Is a directory

# %%
# !pip install dvc
# !pip install 'dvc[gdrive]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 401 kB 35.3 MB/s
# ...
#      |████████████████████████████████| 40 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 235 kB 69.8 MB/s
# ...
#      |████████████████████████████████| 281 kB 72.1 MB/s
# ...
#      |████████████████████████████████| 44 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 41 kB 535 kB/s
# ...
#      |████████████████████████████████| 109 kB 73.0 MB/s
# ...
#      |████████████████████████████████| 346 kB 69.8 MB/s
# ...
#      |████████████████████████████████| 181 kB 74.0 MB/s
# ...
#      |████████████████████████████████| 495 kB 70.1 MB/s
# ...
#      |████████████████████████████████| 4.5 MB 58.9 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 57.6 MB/s
# ...
#      |████████████████████████████████| 140 kB 68.1 MB/s
# ...
#      |████████████████████████████████| 63 kB 932 kB/s
# ...
#      |████████████████████████████████| 322 kB 61.3 MB/s
# ...

# %%
# !dvc init --no-scm
# Out:
# Initialized DVC repository.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/iterative/dvc>

# %%
# !dvc config core.autostage true

# %%
# !dvc add ./lightning-hydra-template/data
# !dvc add ./lightning-hydra-template/logs
# !dvc add ./lightning-hydra-template/model
# Out:
# ⠋ Checking graph
# WARNING: 'lightning-hydra-template/data' is empty.
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
# Computing file/dir hashes (only done once)          |0.00 [00:00,      ?md5/s]
#
# 51713988987e9331980363e24189ce.dir:   0% 0.00/2.00 [00:00<?, ?B/s]
# 51713988987e9331980363e24189ce.dir:   0% 0.00/2.00 [00:00<?, ?B/s{'info': ''}]
# 51713988987e9331980363e24189ce.dir:   0% 0.00/2.00 [00:00<?, ?B/s{'info': ''}]
#
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# Transferring:   0% 0/1 [00:00<?, ?file/s]
# Transferring:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
#
# !
#
#   0%|          |51713988987e9331980363e24189ce.dir 0.00/? [00:00<?,        ?B/s]
#
# 51713988987e9331980363e24189ce.dir:   0% 0.00/2.00 [00:00<?, ?B/s{'info': ''}]
#
#
#
# !
#   0%|          |.ctNwyXQY4oukPSLV6tQxVZ.tmp        0.00/? [00:00<?,        ?B/s]
# .ctNwyXQY4oukPSLV6tQxVZ.tmp:   0% 0.00/4.00 [00:00<?, ?B/s{'info': ''}]
# Adding...: 100% 1/1 [00:00<00:00, 21.50file/s{'info': ''}]
# ...

# %%
# !dvc remote add gdrive gdrive://10MdcuWKsfDLtQPp1UeNJsrQLf3KL8hER

# %%
# !pip install -r ./lightning-hydra-template/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 701 kB 37.9 MB/s
# ...
#      |████████████████████████████████| 419 kB 74.0 MB/s
# ...
#      |████████████████████████████████| 151 kB 62.3 MB/s
# ...
#      |████████████████████████████████| 199 kB 51.9 MB/s
# ...
#      |████████████████████████████████| 509 kB 64.4 MB/s
# ...
#      |████████████████████████████████| 5.9 MB 57.0 MB/s
# ...
#      |████████████████████████████████| 117 kB 73.9 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.2 MB/s
# ...
#      |████████████████████████████████| 308 kB 73.4 MB/s
# ...
#      |████████████████████████████████| 209 kB 73.1 MB/s
# ...
#      |████████████████████████████████| 81 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 8.8 MB 59.3 MB/s
# ...
#      |████████████████████████████████| 98 kB 9.2 MB/s
# ...
#      |████████████████████████████████| 468 kB 72.9 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.6 MB/s
# ...

# %%
# !python ./lightning-hydra-template/src/train.py -m hparams_search=cifar_optuna experiment=cifar_example
# Out:
# Streaming output truncated to the last 5000 lines.
#                                                                val/acc_best:
#                                                                0.647 train/loss:
#                                                                0.882 train/acc:
# Epoch 8    ━━━━━━━━━╸━━━━━━ 118/196 0:00:11 •        10.17it/s loss: 0.811
#                                     0:00:08                    v_num: 0
#                                                                val/loss: 1.037
#                                                                val/acc: 0.647
#                                                                hp_metric: 1.037
#                                                                val/acc_best:
#                                                                0.647 train/loss:
#                                                                0.882 train/acc:
# ...

# %%
# !tensorboard dev upload --logdir ./lightning-hydra-template/logs \
  --name "Simple experiment with CIFAR" \
  --description "Training results from EMLO Assignment03" \
  --one_shot
# Out:
# New experiment created. View your TensorBoard at: https://tensorboard.dev/experiment/Z75EVrieS8yaxRiekAbWgQ/
#
# [2022-09-23T16:18:51] Started scanning logdir.
# [2022-09-23T16:18:53] Total uploaded: 1680 scalars, 60 tensors (360 B), 0 binary objects
# [2022-09-23T16:18:53] Done scanning logdir.
#
#
# Done. View your TensorBoard at https://tensorboard.dev/experiment/Z75EVrieS8yaxRiekAbWgQ/

# %%
# !tensorboard --bind_all --logdir ./lightning-hydra-template/logs/
# Out:
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# TensorBoard 2.10.0 at http://a59080ee5ec2:6006/ (Press CTRL+C to quit)

# %%
# !dvc add ./lightning-hydra-template/data
# !dvc push -r gdrive
# Out:
# ⠋ Checking graph
# Adding...:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# !
# Computing file/dir hashes (only done once)          |0.00 [00:00,      ?md5/s]
# Computing file/dir hashes (only done once)          |3.00 [00:00,   19.4md5/s]
# Computing file/dir hashes (only done once)          |6.00 [00:00,   20.1md5/s]
#
# 843b88ea063643ba3c092d743c2404.dir:   0% 0.00/733 [00:00<?, ?B/s]
# 843b88ea063643ba3c092d743c2404.dir:   0% 0.00/733 [00:00<?, ?B/s{'info': ''}]
# 843b88ea063643ba3c092d743c2404.dir:   0% 0.00/733 [00:00<?, ?B/s{'info': ''}]
#
# !
#   0% |          |0/? [00:00<?,    ?files/s]
#
# Transferring:   0% 0/9 [00:00<?, ?file/s]
# Transferring:   0% 0/9 [00:00<?, ?file/s{'info': ''}]
#
# !
#
#   0%|          |843b88ea063643ba3c092d743c2404.dir 0.00/? [00:00<?,        ?B/s]
#
# 843b88ea063643ba3c092d743c2404.dir:   0% 0.00/733 [00:00<?, ?B/s{'info': ''}]
#
#
#
# !
#   0%|          |.GmrtJXyqnL9J4zeRaKAs8o.tmp        0.00/? [00:00<?,        ?B/s]
# ...

# %%
# !dvc add ./lightning-hydra-template/logs
# !dvc push -r gdrive
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# !
#
#
#
#
#
#
#   0%|          |9b89afde32f93070928df2976ff616     0.00/? [00:00<?,        ?B/s]
#
#
#
#
#
#
# 9b89afde32f93070928df2976ff616:   0% 0.00/45.0 [00:00<?, ?B/s{'info': ''}]
#
#
# 100% 5.25k/5.25k [00:05<00:00, 925B/s{'info': ''}]
#
#
#
#
#
#
#
# Transferring:   4% 8/194 [00:10<02:59,  1.04file/s{'info': ''}]
#
#
#
#
#
#
#
# !
#
#
#
#
#
#
#
#   0%|          |bd4676dec96467aa20b471fc4865ec     0.00/? [00:00<?,        ?B/s]
#
#
#
#
#
#
#
# bd4676dec96467aa20b471fc4865ec:   0% 0.00/2.29k [00:00<?, ?B/s{'info': ''}]
#
#
#
#  86% 8.00k/9.32k [00:05<00:00, 1.61kB/s{'info': ''}]
#
#
# Transferring:   5% 9/194 [00:11<02:57,  1.04file/s{'info': ''}]
#
#
# !
#
#
#   0%|          |81a2363fa1ba6b6c4df8e178c22f6d     0.00/? [00:00<?,        ?B/s]
#
#
# 81a2363fa1ba6b6c4df8e178c22f6d:   0% 0.00/179 [00:00<?, ?B/s{'info': ''}]
# 8c8639a237da5c7c124d7e68e29ed0: 100% 179/179 [00:05<00:00, 35.8B/s{'info': ''}]
#
#
#
# ...
